# %% [markdown]
# <a href="https://colab.research.google.com/github/huwiwi/python/blob/main/Latihan2Kastara.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

x=[1, 2, 3, 4, 5]
y=[10,12,5,8,3]

plt.plot(x, y)

plt.xlabel("Waktu")
plt.ylabel("Nilai")
plt.title("Grafik Garis Contoh")
plt.show()

list_kosong=[]
list_buah=['Pisang', 'Nanas', 'Melon', 'Durian']
list_nilai=[80, 70, 90, 60]
list_jawaban=[150, 33.33, 'Presiden Sukarno', False]

print(list_buah[0])
print(list_buah[1])
print(list_buah[2])
print(list_buah[3])

print(list_nilai[0])
print(list_nilai[1])
print(list_nilai[2])
print(list_nilai[3])

list_hasil=[list_nilai[0], list_nilai[0]+list_nilai[1], 31, 55]
print("List hasil :", list_hasil)

x=[1, 2, 3, 4]
y=list_hasil

plt.plot(x, y)
plt.xlabel("Waktu")
plt.ylabel("Nilai")
plt.title("Grafik Garis Contoh")

plt.savefig("grafik_garis.png")

list_angka=[10,12,14,16,18,20]
list_hasil=[list_angka[0]+list_angka[1]+list_angka[2]+list_angka[3]+list_angka[4]+list_angka[5]]

list_teman=['bu ririn', 'bu ratna', 'bu aktia','bu nungki']
if(len(list_teman)>5):
  print(list_teman)
# Out:
# Pisang
# Nanas
# Melon
# Durian
# 80
# 70
# 90
# 60
# List hasil : [80, 150, 31, 55]

# %%
list_angka=[10,12,14,16,18,20]
list_hasil=[list_angka[0]+list_angka[1]+list_angka[2]+list_angka[3]+list_angka[4]+list_angka[5]]

list_teman=['bu ririn', 'bu ratna', 'bu aktia','bu nungki', 'huhu', 'asdasdasd']

for x in list_teman:
  if(len(x) > 5):
    print(x)
# Out:
# bu ririn
# bu ratna
# bu aktia
# bu nungki
# asdasdasd

# %%
y=[40, 50, 30, 20]
x=[2020, 2021, 2022, 2023]

plt.plot(x,y)
plt.xlabel("Jumlah")
plt.ylabel("Tahun")
plt.title("Grafik Perkembangan Jumlah Siswa")
plt.savefig("grafik_perkembangan.png")
plt.savefig("grafik_perkembanganku.pdf")
